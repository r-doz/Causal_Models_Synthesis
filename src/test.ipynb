# %%
import fitness.data_generating_process as dgp
from fitness.soga_fitness_SCM import *
from utils import *

import numpy as np
from scipy.stats import multivariate_normal

import torch
torch.set_default_dtype(torch.float64)

import time as timeit

# %%
p = """
3\nV1 = 7.3 * gm([89.7, 100.7, 75]) - gm([53, 64, 76.4]);\nif V24 >= 34 { \n   V2 = V94 * V36 * 13.5 + 57 * uniform([78, 38.8], 3) + gm([66.2, 10.2, 69], [15, 93.7, 32.2], [44.1, 39.6, 7.5]); \n } else { \n   if V15 >= 20.8 { \n     if V35 <= 1 { \n       V2 = V72 + V26 * V7 - 1.6 + uniform([63, 35.5], 2); \n     } else { \n       if V16 < 59 { \n         if V31 <= 33.5 { \n           if V54 > 94 { \n             if V22 <= 86 { \n               if V49 >= 79 { \n                 if V0 >= 84.7 { \n                   V2 = 49.4 * 69.2 + 46 * uniform([41, 9], 1); \n                 } else { \n                   if V58 <= 60.5 { \n                     if V75 >= 72.3 { \n                       if V33 > 14 { \n                         V2 = V97 + gm([88.8, 81, 63.5]); \n                       } else { \n                         V2 = V70 * V34 + 81.9 * uniform([80, 11.5], 1) + 32 * uniform([44, 5], 3) + uniform([47, 7], 1) + 71 * uniform([97, 15.4], 3) - gm([28.9, 45, 12.7]) - 37.6 * gm([7.3, 22.2, 12.9], [51, 26.1, 57]) - 0.1 * uniform([88, 9], 2); \n                       } end if; \n                     } else { \n                       if V26 > 73.9 { \n                         V2 = V38 + uniform([90, 77.3], 1); \n                       } else { \n                         if V94 >= 66.9 { \n                           if V60 > 39 { \n                             V2 = 88 - V29 + 71.2 * gm([58.2, 74.2, 21]); \n                           } else { \n                             V2 = 35.9 * V64 * V52 + V51 - 26.6 * V26 + 79 * gm([36.3, 77, 60]) + gm([22, 52.4, 91.3], [88.3, 84, 24.7], [46.9, 37, 92.7], [5.8, 94.4, 29], [94.8, 17, 100], [36, 100, 88]) + 5.5 * gm([43.6, 51.3, 55], [14.1, 36.3, 44], [78, 36.3, 89]); \n                           } end if; \n                         } else { \n                           V2 = V39 + 46 + uniform([31, 5], 1); \n                         } end if; \n                       } end if; \n                     } end if; \n                   } else { \n                     V2 = V7 + gm([78.1, 9, 29.1]); \n                   } end if; \n                 } end if; \n               } else { \n                 if V62 <= 96.8 { \n                   if V66 >= 23 { \n                     V2 = 82 + 80 * gm([16, 100.6, 18], [3.6, 15.4, 47.9], [55, 49.5, 61.6]); \n                   } else { \n                     V2 = 40.3 * V36 * V70 - V30 * V18 - 64.3 + 61 * gm([65.5, 26.6, 80.9]) - gm([96.9, 38.3, 10]) - 95 * gm([16, 87.2, 92.2], [17, 56, 45.9]); \n                   } end if; \n                 } else { \n                   if V51 > 29 { \n                     V2 = 81.9 * 67.5 + 59 * uniform([65, 80.1], 1); \n                   } else { \n                     V2 = 38 * 94.6 * 67 - 59.3 + V88 * 97 * 34.3 - V66 * 39.4 + 39.7 * uniform([11, 98.9], 1) - 94 * gm([93, 76, 40.5], [85, 27.6, 15]) - gm([95, 97.7, 72]) - 9.7 * uniform([19, 9], 3); \n                   } end if; \n                 } end if; \n               } end if; \n             } else { \n               if V87 >= 6 { \n                 V2 = V4 + V85 + 78 + 38 * uniform([3, 3], 3) - gm([45, 32.6, 37]); \n               } else { \n                 V2 = V74 - V56 * V33 + 85 * gm([24.1, 44, 29.7]) + gm([19.4, 1, 65]); \n               } end if; \n             } end if; \n           } else { \n             V2 = 4.6 * 13.9 * V59 + gm([32.2, 70, 54.2], [62, 19.2, 7.3], [72, 89.7, 100.7]) + 1.9 * uniform([34, 55.4], 2); \n           } end if; \n         } else { \n           if V75 >= 60 { \n             V2 = 52.2 + V52 * 86.1 + 57 * uniform([78, 38.8], 3); \n           } else { \n             V2 = 10.2 * V7 * V62 * V5 - V44 + gm([77, 19, 20.8], [46, 0, 1], [93.6, 23, 72]) + gm([86, 7, 37.4]) - 19.4 * uniform([63, 35.5], 2) - gm([59, 10.2, 44.4]); \n           } end if; \n         } end if; \n       } else { \n         if V30 < 44 { \n           V2 = 86 * 1.4 * 79 * 34 + uniform([65, 4], 1); \n         } else { \n           V2 = V46 * 41.6 - V8 * 19 * 82.4 - V11 * V52 + V36 * V74 - V46 - V63 * V7 - V70 + gm([80.8, 45.9, 81.9], [80, 11.5, 38.1], [67, 44, 63]); \n         } end if; \n       } end if; \n     } end if; \n   } else { \n     V2 = V72 * V99 * 54.7 * 46 + 30 * gm([7.7, 27.8, 37.6]) + 34.2 * gm([100.8, 57, 51], [68.1, 39, 50], [89, 88.6, 82.2], [26, 36, 72], [78, 30, 39.4]) - gm([93, 99.1, 66.4], [20, 62, 55.2]) + 99.5 * uniform([88, 64.7], 3); \n   } end if; \n } end if;\nif V92 <= 44.3 { \n   V3 = 91.7 * 93 - 75.7 * 48 * V51 - 26.6 * V26 - V79 * V62 - V77 + V62 - V52 * 91.3 + 84 * uniform([10, 89.2], 3) + 92.7 * uniform([5, 37.2], 1) + 19.9 * uniform([17, 2], 2); \n } else { \n   V3 = 88 + 5.5 * gm([43.6, 51.3, 55], [14.1, 36.3, 44], [78, 36.3, 89]); \n } end if;


"""
perm, p = extract_perm_and_strip_program(p)
p = normalize_program_by_blocks(p)
data_var_list, scm = dgp.get_vars("causal_skills")
mapping = perm_to_mapping(perm, data_var_list)
p = preprocess_program(p)
print(p)
p = replace_variables_with_names(p, mapping)
print(p)

compiledText=compile2SOGA_text(p)
cfg = produce_cfg_text(compiledText)
output_dist = start_SOGA(cfg)
#soga_bf = preprocess_program(program)
# Out:
# V1 = 7.3 * gm([1.000000], [100.7], [75]);V1 = V1 - gm([1.000000], [64], [76.4]);if V1 >= 34 {   TEMP0 = V1 * V1;   TEMP0 = 13.5 * TEMP0;   V2 = TEMP0;   V2 = V2 + 57 * uniform([78.000000, 116.800000], 3);   V2 = V2 + gm([0.528332, 0.119713, 0.351955], [10.2, 93.7, 39.6], [69, 32.2, 7.5]); } else {   if V1 >= 20.8 {     if V1 <= 1 {       TEMP1 = V1 * V1;       V2 = V1;       V2 = V2 + TEMP1;       V2 = V2 - 1.6;       V2 = V2 + uniform([63.000000, 98.500000], 2);     } else {       if V1 < 59 {         if V1 <= 33.5 {           if V1 > 94 {             if V1 <= 86 {               if V1 >= 79 {                 if V1 >= 84.7 {                   V2 = 3418.48;                   V2 = V2 + 46 * uniform([41.000000, 50.000000], 1);                 } else {                   if V1 <= 60.5 {                     if V1 >= 72.3 {                       if V1 > 14 {                         V2 = V1;                         V2 = V2 + gm([1.000000], [81], [63.5]);                       } else {       
# ...

# %%
p = """
belief = 7.3 * gm([1.000000], [100.7], [75]);
belief = belief - gm([1.000000], [64], [76.4]);
if belief >= 34 {   
    TEMP0 = belief * belief;   
    TEMP0 = 13.5 * TEMP0;   
    skill = TEMP0;   
    skill = skill + 57 * uniform([78.000000, 116.800000], 3);   
    skill = skill + gm([0.528332, 0.119713, 0.351955], [10.2, 93.7, 39.6], [69, 32.2, 7.5]); 
} else {   
    if belief >= 20.8 {     
        if belief <= 1 {       
            TEMP1 = belief * belief;       
            skill = belief;       
            skill = skill + TEMP1;       
            skill = skill - 1.6;       
            skill = skill + uniform([63.000000, 98.500000], 2);     
        } else {       
            if belief < 59 {         
                if belief <= 33.5 {           
                    if belief > 94 {             
                        if belief <= 86 {               
                            if belief >= 79 {                 
                                if belief >= 84.7 {                   
                                    skill = 3418.48;                   
                                    skill = skill + 46 * uniform([41.000000, 50.000000], 1);                 
                                } else {                   
                                    if belief <= 60.5 {                     
                                        if belief >= 72.3 {                       
                                            if belief > 14 {                         
                                                skill = belief;                         
                                                skill = skill + gm([1.000000], [81], [63.5]);                       
                                            } else {                         
                                                TEMP2 = belief * belief;                        
                                                skill = TEMP2;                         
                                                skill = skill + 81.9 * uniform([80.000000, 91.500000], 1);                         
                                                skill = skill + 32 * uniform([44.000000, 49.000000], 3);                         
                                                skill = skill + uniform([47.000000, 54.000000], 1);                         
                                                skill = skill + 71 * uniform([97.000000, 112.400000], 3);                         
                                                skill = skill - gm([1.000000], [45], [12.7]);                         
                                                skill = skill - 37.6 * gm([0.125214, 0.874786], [22.2, 26.1], [12.9, 57]);                         
                                                skill = skill - 0.1 * uniform([88.000000, 97.000000], 2);                      
                                            } end if;                    
                                        } else {                       
                                            if belief > 73.9 {                         skill = belief;                         skill = skill + uniform([90.000000, 167.300000], 1);                       } else {                         if belief >= 66.9 {                           if belief > 39 {                             skill = 88;                             skill = skill - belief;                             skill = skill + 71.2 * gm([1.000000], [74.2], [21]);                           } else {                             TEMP3 = 35.9 * belief;                             TEMP3 = TEMP3 * belief;                             TEMP4 = 26.6 * belief;                             skill = TEMP3;                             skill = skill + belief;                             skill = skill - TEMP4;                             skill = skill + 79 * gm([1.000000], [77], [60]);                             skill = skill + gm([0.074881, 0.300545, 0.159632, 0.019741, 0.322668, 0.122532], [52.4, 84, 37, 94.4, 17, 100], [91.3, 24.7, 92.7, 29, 100, 88]);                             skill = skill + 5.5 * gm([0.321297, 0.103906, 0.574797], [51.3, 36.3, 36.3], [55, 44, 89]);                           } end if;                         } else {                           skill = belief;                           skill = skill + 46;                           skill = skill + uniform([31.000000, 36.000000], 1);                         } end if;                       } end if;                     } end if;                   } else {                     skill = belief;                     skill = skill + gm([1.000000], [9], [29.1]);                   } end if;                 } end if;               } else {                 if belief <= 96.8 {                   if belief >= 23 {                     skill = 82;                     skill = skill + 80 * gm([0.214477, 0.048257, 0.737265], [100.6, 15.4, 49.5], [18, 47.9, 61.6]);                   } else {                     TEMP5 = 40.3 * belief;                     TEMP5 = TEMP5 * belief;                     TEMP6 = belief * belief;                     skill = TEMP5;                     skill = skill - TEMP6;                     skill = skill - 64.3;                     skill = skill + 61 * gm([1.000000], [26.6], [80.9]);                     skill = skill - gm([1.000000], [38.3], [10]);                     skill = skill - 95 * gm([0.484848, 0.515152], [87.2, 56], [92.2, 45.9]);                   } end if;                 } else {                   if belief > 29 {                     skill = 5528.25;                     skill = skill + 59 * uniform([65.000000, 145.100000], 1);                   } else {                     TEMP7 = 3327.1 * belief;                     TEMP8 = 39.4 * belief;                     skill = 240851.59999999998;                     skill = skill - 59.3;                     skill = skill + TEMP7;                     skill = skill - TEMP8;                     skill = skill + 39.7 * uniform([11.000000, 109.900000], 1);                     skill = skill - 94 * gm([0.522472, 0.477528], [76, 27.6], [40.5, 15]);                     skill = skill - gm([1.000000], [97.7], [72]);                     skill = skill - 9.7 * uniform([19.000000, 28.000000], 3);                   } end if;                 } end if;               } end if;             } else {               if belief >= 6 {                 skill = belief;                 skill = skill + belief;                 skill = skill + 78;                 skill = skill + 38 * uniform([3.000000, 6.000000], 3);                 skill = skill - gm([1.000000], [32.6], [37]);               } else {                 TEMP9 = belief * belief;                 skill = belief;                 skill = skill - TEMP9;                 skill = skill + 85 * gm([1.000000], [44], [29.7]);                 skill = skill + gm([1.000000], [1], [65]);               } end if;             } end if;           } else {             TEMP10 = 63.94 * belief;             skill = TEMP10;             skill = skill + gm([0.193742, 0.373045, 0.433213], [70, 19.2, 89.7], [54.2, 7.3, 100.7]);             skill = skill + 1.9 * uniform([34.000000, 89.400000], 2);           } end if;         } else {           if belief >= 60 {             TEMP11 = 86.1 * belief;             skill = 52.2;             skill = skill + TEMP11;             skill = skill + 57 * uniform([78.000000, 116.800000], 3);           } else {             TEMP12 = 10.2 * belief;             TEMP12 = TEMP12 * belief;             TEMP12 = TEMP12 * belief;             skill = TEMP12;             skill = skill - belief;             skill = skill + gm([0.355494, 0.212373, 0.432133], [19, 0, 23], [20.8, 1, 72]);             skill = skill + gm([1.000000], [7], [37.4]);             skill = skill - 19.4 * uniform([63.000000, 98.500000], 2);             skill = skill - gm([1.000000], [10.2], [44.4]);           } end if;         } end if;       } else {         if belief < 44 {           skill = 323394.39999999997;           skill = skill + uniform([65.000000, 69.000000], 1);         } else {           TEMP13 = 41.6 * belief;           TEMP14 = 1565.6000000000001 * belief;           TEMP15 = belief * belief;           skill = TEMP13;           skill = skill - TEMP14;           skill = skill - TEMP15;           skill = skill + TEMP15;           skill = skill - belief;           skill = skill - TEMP15;           skill = skill - belief;           skill = skill + gm([0.354697, 0.351185, 0.294118], [45.9, 11.5, 44], [81.9, 38.1, 63]);         } end if;       } end if;     } end if;   } else {     TEMP16 = belief * belief;     TEMP16 = 54.7 * TEMP16;     TEMP16 = 46 * TEMP16;     skill = TEMP16;     skill = skill + 30 * gm([1.000000], [27.8], [37.6]);     skill = skill + 34.2 * gm([0.278530, 0.188174, 0.245924, 0.071843, 0.215529], [57, 39, 88.6, 36, 30], [51, 50, 82.2, 72, 39.4]);     skill = skill - gm([0.823009, 0.176991], [99.1, 62], [66.4, 55.2]);     skill = skill + 99.5 * uniform([88.000000, 152.700000], 3);   } end if; } end if;if skill <= 44.3 {   TEMP17 = 3633.6000000000004 * belief;   TEMP18 = 26.6 * skill;   TEMP19 = belief * skill;   TEMP20 = 91.3 * skill;   result = 8528.1;   result = result - TEMP17;   result = result - TEMP18;   result = result - TEMP19;   result = result - belief;   result = result + skill;   result = result - TEMP20;   result = result + 84 * uniform([10.000000, 99.200000], 3);   result = result + 92.7 * uniform([5.000000, 42.200000], 1);   result = result + 19.9 * uniform([17.000000, 19.000000], 2); } else {   result = 88;   result = result + 5.5 * gm([0.321297, 0.103906, 0.574797], [51.3, 36.3, 36.3], [55, 44, 89]); } end if;

"""
compiledText=compile2SOGA_text(p)
cfg = produce_cfg_text(compiledText)
output_dist = start_SOGA(cfg)
# Out:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# /tmp/ipykernel_272797/2522511238.py in ?()
#      46
#      47 """
#      48 compiledText=compile2SOGA_text(p)
#      49 cfg = produce_cfg_text(compiledText)
# ---> 50 output_dist = start_SOGA(cfg)
#
# ~/PhD/Causal_Models_Synthesis/src/../SOGA-main/src/libSOGA.py in ?(cfg, pruning, Kmax, parallel, useR)
#      34     exec_queue = [cfg.root]
#      35
#      36     # executes SOGA on nodes on exec_queue
#      37     while(len(exec_queue)>0):
# ---> 38         SOGA(exec_queue.pop(0), data, parallel, exec_queue)
#      39
#      40     # returns output distribution
#      41     p, current_dist = merge(cfg.node_list['exit'].list_dist)
#
# ~/PhD/Causal_Models_Synthesis/src/../SOGA-main/src/libSOGA.py in ?(node, data, parallel, exec_queue)
#     114                 current_trunc = negate(current_trunc)
# ...
